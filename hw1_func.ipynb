# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 15, 500)
k=1
plt.plot(x, np.cos(k*x), marker='o')

# %%
x = np.linspace(0, 15, 500)
k=5
plt.plot(x, np.cos(k*x), marker='o')
